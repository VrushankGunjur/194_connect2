# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

cred = credentials.Certificate("./cs194-e95a9-firebase-adminsdk-2c109-76ac75a7fa.json")
#databaseURL = 'https://cs194-e95a9.firebaseapp.com'
firebase_admin.initialize_app(cred, {'databaseURL': 'https://cs194-e95a9.firebaseapp.com'})

# %%
db.reference('users').get()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 db.reference('users').get()
#
# File /opt/homebrew/lib/python3.11/site-packages/firebase_admin/db.py:69, in reference(path, app, url)
#      49 """Returns a database ``Reference`` representing the node at the specified path.
#      50
#      51 If no path is specified, this function returns a ``Reference`` that represents the database
#    (...)
#      66   ValueError: If the specified path or app is invalid.
#      67 """
#      68 service = _utils.get_app_service(app, _DB_ATTRIBUTE, _DatabaseService)
# ---> 69 client = service.get_client(url)
#      70 return Reference(client=client, path=path)
#
# File /opt/homebrew/lib/python3.11/site-packages/firebase_admin/db.py:798, in _DatabaseService.get_client(self, db_url)
#     795     db_url = self._db_url
# ...

# %%
ref.get()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/firebase_admin/db.py:929, in _Client.request(self, method, url, **kwargs)
#     928 try:
# --> 929     return super(_Client, self).request(method, url, **kwargs)
#     930 except requests.exceptions.RequestException as error:
#
# File /opt/homebrew/lib/python3.11/site-packages/firebase_admin/_http_client.py:119, in HttpClient.request(self, method, url, **kwargs)
#     118 resp = self._session.request(method, self.base_url + url, **kwargs)
# --> 119 resp.raise_for_status()
#     120 return resp
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# ...
