# %%
import pandas as pd

# %%
data = pd.read_json('geonames-all-cities-with-a-population-1000.json')

# %%
data
# Out:
#         geoname_id                       name                 ascii_name  \
# 0          8859534  Profresor Roberto Barrios  Profresor Roberto Barrios
# 1          8859539        Progreso (Campo 47)        Progreso (Campo 47)
# 2          8859548        Santiago Ixtaltepec        Santiago Ixtaltepec
# 3          8859635         Estación la Piedad         Estacion la Piedad
# 4          8859653            Valle de Juárez            Valle de Juarez
# ...            ...                        ...                        ...
# 146952     2686674                    Örbyhus                   OErbyhus
# 146953     2694529                  Ljungsbro                  Ljungsbro
# 146954     2695016                   Limmared                   Limmared
# 146955     2697295                Långshyttan                Langshyttan
# 146956     2697727                   Landsbro                   Landsbro
#
#                                  alternate_names feature_class feature_code  \
# 0                    [Profresor Roberto Barrios]             P          PPL
# 1                          [Progreso (Campo 47)]             P          PPL
# 2                          [Santiago Ixtaltepec]             P          PPL
# 3       [Estacion la Piedad, Estación la Piedad]             P          PPL
# 4             [Valle de Juarez, Valle de Juárez]             P          PPL
# ...                                          ...           ...          ...
# 146952     [OErbyhus, Orbyhus, Örbyhus, Ørbyhus]             P          PPL
# 146953                     [Ljugsbro, Ljungsbro]             P          PPL
# 146954                                [Limmared]             P          PPL
# 146955                [Langshyttan, Långshyttan]             P          PPL
# 146956                                [Landsbro]             P          PPL
#
#        country_code cou_name_en country_code_2 admin1_code admin2_code  \
# 0                MX      Mexico           None          05         065
# 1                MX      Mexico           None          26         018
# 2                MX      Mexico           None          20         005
# 3                MX      Mexico           None          11         023
# 4                MX      Mexico           None          19         031
# ...             ...         ...            ...         ...         ...
# 146952           SE      Sweden           None          21        0360
# 146953           SE      Sweden           None          16        0580
# 146954           SE      Sweden           None          28        1452
# 146955           SE      Sweden           None          10        2083
# 146956           SE      Sweden           None          08        0685
#
#        admin3_code admin4_code  population  elevation   dem  \
# 0             None        None        1173        NaN   156
# 1             None        None        1170        NaN    16
# 2             None        None        1164        NaN   236
# 3             None        None        1123        NaN  1681
# 4             None        None        1119        NaN   455
# ...            ...         ...         ...        ...   ...
# 146952      036003        0289        2025        NaN    23
# 146953        None        None        6763        NaN    68
# 146954      145205        1725        1434        NaN   169
# 146955        None        None        1609        NaN   104
# 146956        None        None        1438        NaN   205
#
#                    timezone modification_date label_en  \
# 0       America/Mexico_City        2014-04-11   Mexico
# 1        America/Hermosillo        2014-04-11   Mexico
# 2       America/Mexico_City        2014-04-11   Mexico
# 3       America/Mexico_City        2014-04-11   Mexico
# 4         America/Monterrey        2014-04-11   Mexico
# ...                     ...               ...      ...
# 146952     Europe/Stockholm        2017-03-18   Sweden
# 146953     Europe/Stockholm        2017-03-18   Sweden
# 146954     Europe/Stockholm        2017-03-18   Sweden
# 146955     Europe/Stockholm        2017-03-19   Sweden
# 146956     Europe/Stockholm        2022-05-16   Sweden
#
#                                  coordinates
# 0        {'lon': -91.92639, 'lat': 17.32583}
# 1       {'lon': -110.09361, 'lat': 27.34028}
# 2        {'lon': -94.90583, 'lat': 16.68833}
# 3        {'lon': -101.99806, 'lat': 20.3675}
# 4       {'lon': -100.15833, 'lat': 25.63778}
# ...                                      ...
# 146952    {'lon': 17.70138, 'lat': 60.22407}
# 146953        {'lon': 15.5, 'lat': 58.51667}
# 146954    {'lon': 13.35566, 'lat': 57.53592}
# 146955    {'lon': 16.03831, 'lat': 60.45238}
# 146956        {'lon': 14.9, 'lat': 57.36667}
#
# [146957 rows x 20 columns]

# %%
data = data[['name', 'cou_name_en', 'coordinates', 'population']]

# %%
data
# Out:
#                              name cou_name_en  \
# 0       Profresor Roberto Barrios      Mexico
# 1             Progreso (Campo 47)      Mexico
# 2             Santiago Ixtaltepec      Mexico
# 3              Estación la Piedad      Mexico
# 4                 Valle de Juárez      Mexico
# ...                           ...         ...
# 146952                    Örbyhus      Sweden
# 146953                  Ljungsbro      Sweden
# 146954                   Limmared      Sweden
# 146955                Långshyttan      Sweden
# 146956                   Landsbro      Sweden
#
#                                  coordinates  population
# 0        {'lon': -91.92639, 'lat': 17.32583}        1173
# 1       {'lon': -110.09361, 'lat': 27.34028}        1170
# 2        {'lon': -94.90583, 'lat': 16.68833}        1164
# 3        {'lon': -101.99806, 'lat': 20.3675}        1123
# 4       {'lon': -100.15833, 'lat': 25.63778}        1119
# ...                                      ...         ...
# 146952    {'lon': 17.70138, 'lat': 60.22407}        2025
# 146953        {'lon': 15.5, 'lat': 58.51667}        6763
# 146954    {'lon': 13.35566, 'lat': 57.53592}        1434
# 146955    {'lon': 16.03831, 'lat': 60.45238}        1609
# 146956        {'lon': 14.9, 'lat': 57.36667}        1438
#
# [146957 rows x 4 columns]
